# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import os
import re
import unittest

# %% [markdown]
# -----

# %% [markdown]
# # Leitura Inferências

# %%
df = pd.read_csv(
    '../../../2_0_PREPROCESSING_INFERENCES/CodeLLaMA-13B/generated_tests_codellama13b_nvidia_api_adjusted.csv',
    sep=',',
    header=0
)

# %% [markdown]
# # Executando os Unit Testes Gerados

# %%
outputs = []

for index, row in df.iterrows():
    prompt = row['prompt']
    canonical_solution = row['canonical_solution']
    generated_solution = row['generated_solution']
    
    regex = r"class\s+(\w+)"
    match = re.search(regex, generated_solution)
    test_class_name = match.group(1)
    
    # print(prompt + canonical_solution + generated_solution)
    exec(prompt + canonical_solution + generated_solution)
    print(test_class_name)
    print("--------------------")
    loader = unittest.TestLoader()
    suite = loader.loadTestsFromTestCase(globals()[test_class_name])
    
    runner = unittest.TextTestRunner()
    result = runner.run(suite)

    # print("Total de testes executados:", result.testsRun)
    # print("Testes com falhas:", len(result.failures))
    # print("Testes com erros:", len(result.errors))
    
    correctness = 1 if len(result.failures) == 0 and len(result.errors) == 0 else 0
    
    outputs.append([index, result.testsRun, len(result.failures), len(result.errors), correctness])
# Out:
# .F.F..F.F.
# ...
# FAIL: test_five_close_elements (__main__.TestHasCloseElements.test_five_close_elements)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<string>", line 46, in test_five_close_elements
# AssertionError: False is not true
#
# ...
# FAIL: test_four_close_elements (__main__.TestHasCloseElements.test_four_close_elements)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<string>", line 40, in test_four_close_elements
# AssertionError: False is not true
#
# ...
# FAIL: test_three_close_elements (__main__.TestHasCloseElements.test_three_close_elements)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<string>", line 34, in test_three_close_elements
# AssertionError: False is not true
#
# ...
# FAIL: test_two_close_elements (__main__.TestHasCloseElements.test_two_close_elements)
# ...

# %% [markdown]
# # Salvando Resultados

# %%
df = pd.DataFrame(outputs, columns=['index', 'tests_run', 'failures', 'errors', 'correctness'])

df.to_csv('eval_test_codellama13b.csv', index=False)
